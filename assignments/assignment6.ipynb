# %%
# Defining imports
import os

import numpy as np
import matplotlib.pyplot as plt

# %%
# Defining constants
h_over_H = np.arange(0, 1.1, 0.1)
x_over_H = 2 * np.sqrt((1 - h_over_H) * h_over_H)

# %%
# Finding the maximum value of x|/H
maxIndex = np.argmax(x_over_H)

# %%
# Plotting the graph
plt.plot(h_over_H, x_over_H)
plt.plot(h_over_H[maxIndex], x_over_H[maxIndex], 'ro')
plt.grid("--")
plt.xlabel('h/H')
plt.ylabel('x/H')
plt.savefig('oving6-oppg3.png')

plt.show()
